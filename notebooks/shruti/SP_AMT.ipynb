# %%
import numpy as np
import tensorflow as tf
import tensorflow_hub as hub
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score
import warnings
warnings.filterwarnings("ignore")

# %%
USE_URL       = "https://tfhub.dev/google/universal-sentence-encoder/4"   # DAN
# USE_URL     = "https://tfhub.dev/google/universal-sentence-encoder-large/5"  # Transformer

BATCH_SIZE    = 32
EPOCHS        = 10
LSTM_UNITS    = 100      # dl — matches paper
ATTN_UNITS    = 100      # da — matches paper
SHARED_UNITS  = 100      # ds — matches paper
LEARNING_RATE = 1e-4     # Adam lr — matches paper
LAMBDA        = 0.5      # loss weight for shared (eq.17)
TEST_SIZE     = 0.2
RANDOM_SEED   = 42

# %%
import pandas as pd
import nltk
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Download the VADER lexicon (only needs to be done once)
nltk.download('vader_lexicon')
analyzer = SentimentIntensityAnalyzer()

print("Loading dataset...")
df = pd.read_csv(r"C:\Users\chouh\OneDrive\Desktop\VirginiaTech\Spring 2026\SocialMediaAnalytics\FinalProject\archive\twitter_sentiment_data.csv")
df = df.dropna(subset=["message"])
df["message"] = df["message"].astype(str).str.strip()

# Sentiment Classification (Independent of Stance)

def get_vader_sentiment(text):
    # compound score ranges from -1 (Extremely Negative) to 1 (Extremely Positive)
    score = analyzer.polarity_scores(text)['compound']
    if score <= -0.05:
        return 0  # Negative
    elif score >= 0.05:
        return 2  # Positive
    else:
        return 1  # Neutral

# Apply VADER to the actual text content
df["sentiment_label"] = df["message"].apply(get_vader_sentiment)

# Stance: mapping based on the original Kaggle 'sentiment' column
# We keep this as is because 'sentiment' in this CSV is actually the 'Stance'
stance_df = df[(df["sentiment"] != 0) & (df["sentiment"] != 2)].copy()
stance_df["stance_label"] = stance_df["sentiment"].map({-1: 0, 1: 1})

# ── Summary Prints ──────────────────────────────────────────────────────
print(f"\nDataset : {len(df):,} total  |  {len(stance_df):,} for stance (neutral and news category excluded)")
print("\n── Independent Sentiment (VADER) ──")
for k, n in {0: "Negative", 1: "Neutral", 2: "Positive"}.items():
    print(f"  {n:10s}: {(df['sentiment_label']==k).sum():,}")

print("\n── Stance (Kaggle Labels) ────────")
for k, n in {0: "Denier", 1: "Believer"}.items():
    print(f"  {n:10s}: {(stance_df['stance_label']==k).sum():,}")
print()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\chouh\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# Loading dataset...
#
# Dataset : 43,943 total  |  26,952 for stance (neutral and news category excluded)
#
# ── Independent Sentiment (VADER) ──
#   Negative  : 16,581
#   Neutral   : 11,377
#   Positive  : 15,985
#
# ── Stance (Kaggle Labels) ────────
#   Denier    : 3,990
#   Believer  : 22,962

# %%
#Load USE
use_model = hub.load(USE_URL)
print("USE loaded. \n")

def encode_texts(texts, batch_size=256):
    embeddings = []
    for i in range(0, len(texts), batch_size):
        emb = use_model(texts[i: i + batch_size]).numpy()
        embeddings.append(emb)
    return np.vstack(embeddings)
# Out:
# USE loaded.

# %%
# Load and Encode iSarcasm Dataset

isarcasm_df = pd.read_csv(r"C:\Users\chouh\OneDrive\Desktop\VirginiaTech\Spring 2026\SocialMediaAnalytics\FinalProject\archive\train.En.csv")  # Ensure this file is in your project folder

# We use your existing function to keep the embedding space consistent
X_sarcasm = encode_texts(isarcasm_df["tweet"].astype(str).tolist())
X_sarcasm_seq = np.expand_dims(X_sarcasm, axis=1)
y_sarcasm = isarcasm_df["sarcastic"].values

#Build the Sarcasm Knowledge Extraction Model ---
s_inp = tf.keras.Input(shape=(1, 512))
# We name this layer so we can easily steal its weights later
s_bilstm_layer = tf.keras.layers.Bidirectional(
    tf.keras.layers.LSTM(LSTM_UNITS, return_sequences=True), name="sarcasm_bilstm"
)(s_inp)
s_out = tf.keras.layers.Dense(1, activation='sigmoid')(tf.keras.layers.Flatten()(s_bilstm_layer))

s_expert = tf.keras.Model(s_inp, s_out)
s_expert.compile(optimizer='adam', loss='binary_crossentropy')

# Train for a few epochs to capture the tonal patterns
s_expert.fit(X_sarcasm_seq, y_sarcasm, epochs=5, batch_size=32, verbose=1)

# Extract the learned weights
sarcasm_weights = s_expert.get_layer("sarcasm_bilstm").get_weights()
# Out:
# Epoch 1/5
# 109/109 [==============================] - 6s 21ms/step - loss: 0.5851
# Epoch 2/5
# 109/109 [==============================] - 3s 24ms/step - loss: 0.5411
# Epoch 3/5
# 109/109 [==============================] - 4s 32ms/step - loss: 0.5230
# Epoch 4/5
# 109/109 [==============================] - 5s 42ms/step - loss: 0.5110
# Epoch 5/5
# 109/109 [==============================] - 4s 39ms/step - loss: 0.5033

# %%
# USE 512-dim sentence vector. Reshape to (N, 1, 512) for BiLSTM.
X_stance = encode_texts(stance_df["message"].tolist())   # (N, 512)
X_stance_seq = np.expand_dims(X_stance, axis=1)          # (N, 1, 512)
print(f"Embedding shape: {X_stance.shape} :  BiLSTM input: {X_stance_seq.shape}\n")

y_stance    = stance_df["stance_label"].values
y_sentiment = stance_df["sentiment_label"].values

# Train / Test Split
(X_train, X_test,
 y_st_train, y_st_test,
 y_se_train, y_se_test) = train_test_split(
    X_stance_seq, y_stance, y_sentiment,
    test_size=TEST_SIZE, random_state=RANDOM_SEED, stratify=y_stance)
# Out:
# Embedding shape: (26952, 512) :  BiLSTM input: (26952, 1, 512)

# %%
class SelfAttention(tf.keras.layers.Layer):
    """
    Scaled dot-product self-attention (eq. 1 in paper).
    SAj = softmax(Qj · Kj^T / sqrt(da)) · Vj
    """
    def __init__(self, units, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.units = units
        self.Wq = tf.keras.layers.Dense(units)
        self.Wk = tf.keras.layers.Dense(units)
        self.Wv = tf.keras.layers.Dense(units)

    def call(self, x):
        Q, K, V = self.Wq(x), self.Wk(x), self.Wv(x)
        scale   = tf.math.sqrt(tf.cast(self.units, tf.float32))
        weights = tf.nn.softmax(tf.matmul(Q, K, transpose_b=True) / scale, axis=-1)
        return tf.matmul(weights, V)


class InterAttention(tf.keras.layers.Layer):
    """
    Inter-attention (eq. 2,3 in paper):
    IAxy = softmax(Qx · Ky^T / sqrt(da)) · Vy
    Uses Q from source x and K,V from source y.
    """
    def __init__(self, units, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.units = units
        self.Wq = tf.keras.layers.Dense(units)
        self.Wk = tf.keras.layers.Dense(units)
        self.Wv = tf.keras.layers.Dense(units)

    def call(self, x, y):
        Q       = self.Wq(x)
        K, V    = self.Wk(y), self.Wv(y)
        scale   = tf.math.sqrt(tf.cast(self.units, tf.float32))
        weights = tf.nn.softmax(tf.matmul(Q, K, transpose_b=True) / scale, axis=-1)
        return tf.matmul(weights, V)


class GateSharingCell(tf.keras.layers.Layer):
    """
    Gate Sharing Cell (eq. 8,9 in paper):
      gd   = σ(Wd · Ashared + bd)
      Gd   = gd ⊙ Ashared
    Filters shared features relevant to a specific task.
    """
    def __init__(self, units, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.gate_dense = tf.keras.layers.Dense(units, activation="sigmoid")

    def call(self, A_task, A_shared):
        # Weights from A_task passed to gate, applied to A_shared
        gate = self.gate_dense(A_task)
        return gate * A_shared


class SPIALayer(tf.keras.layers.Layer):
    """
    Shared-Private Inter-Attention (eq. 11,12 in paper):
      SPIAd = softmax(Qd · Kshared^T) · Vshared
    Captures shared features relevant to a specific task.
    """
    def __init__(self, units, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.units  = units
        self.Wq     = tf.keras.layers.Dense(units)
        self.Wk     = tf.keras.layers.Dense(units)
        self.Wv     = tf.keras.layers.Dense(units)

    def call(self, A_task, A_shared):
        Q       = self.Wq(A_task)
        K, V    = self.Wk(A_shared), self.Wv(A_shared)
        scale   = tf.math.sqrt(tf.cast(self.units, tf.float32))
        weights = tf.nn.softmax(tf.matmul(Q, K, transpose_b=True) / scale, axis=-1)
        return tf.matmul(weights, V)


class FusionLayer(tf.keras.layers.Layer):
    """
    Fusion (eq. 13-16 in paper):
      C  = [G; SPIA; G-SPIA; G⊙SPIA]
      Fshared = tanh(Wf · C + bf)
    """
    def __init__(self, units, name=None, **kwargs):
        super().__init__(name=name, **kwargs)
        self.dense = tf.keras.layers.Dense(units, activation="tanh")

    def call(self, G, SPIA):
        C = tf.concat([G, SPIA, G - SPIA, G * SPIA], axis=-1)
        return self.dense(C)

# Build SP-AMT Model

def build_sp_amt():
    """
    Shared-Private Attention Multi-Task Model (SP-AMT).

    Since USE produces a single sentence vector (no token sequence),
    we use seq_len=1. Both private and shared BiLSTMs operate over
    this single time-step, and attention is applied over the hidden
    states.
    """
    inp = tf.keras.Input(shape=(1, 512), name="use_embedding")

    # Private BiLSTMs (task-specific feature extraction with Sarcasm Injection)
    private_stance_layer = tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(LSTM_UNITS, return_sequences=True),
        name="bilstm_private_stance")


    private_stance_layer.build(input_shape=(None, 1, 512))
    private_stance_layer.set_weights(sarcasm_weights)

    bilstm_private_stance = private_stance_layer(inp)

    bilstm_private_sent = tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(LSTM_UNITS, return_sequences=True),
        name="bilstm_private_sentiment")(inp)               # (B, 1, 2*dl)

    #Shared BiLSTM (task-invariant features)
    bilstm_shared = tf.keras.layers.Bidirectional(
        tf.keras.layers.LSTM(LSTM_UNITS, return_sequences=True),
        name="bilstm_shared")(inp)                          # (B, 1, 2*dl)

    # Feature-Specific Attention (eq. 1-6)
    # For Stance (private):  SA + IA(private_stance ↔ shared)
    sa_stance  = SelfAttention(ATTN_UNITS, name="SA_stance")(bilstm_private_stance)
    ia_stance  = InterAttention(ATTN_UNITS, name="IA_stance_shared")(
                    bilstm_private_stance, bilstm_shared)
    Ad = tf.concat([sa_stance, ia_stance], axis=-1)         # eq. 5

    # For Sentiment (private): SA + IA(private_sent ↔ shared)
    sa_sent    = SelfAttention(ATTN_UNITS, name="SA_sentiment")(bilstm_private_sent)
    ia_sent    = InterAttention(ATTN_UNITS, name="IA_sentiment_shared")(
                    bilstm_private_sent, bilstm_shared)
    As = tf.concat([sa_sent, ia_sent], axis=-1)             # eq. 6

    #Shared Attention: Ashared = average(Ad, As)  (eq. 7)
    A_shared = tf.keras.layers.Average(name="A_shared")([Ad, As])

    #Gate Sharing Cell (eq. 8,9,10)
    Gd = GateSharingCell(SHARED_UNITS * 2, name="gate_stance")(Ad, A_shared)
    Gs = GateSharingCell(SHARED_UNITS * 2, name="gate_sentiment")(As, A_shared)

    #SPIA (eq. 11,12)
    SPIAd = SPIALayer(SHARED_UNITS * 2, name="SPIA_stance")(Ad, A_shared)
    SPIAs = SPIALayer(SHARED_UNITS * 2, name="SPIA_sentiment")(As, A_shared)

    # Fusion (eq. 13-16)
    Fd_shared = FusionLayer(SHARED_UNITS * 2, name="fusion_stance")(Gd, SPIAd)
    Fs_shared = FusionLayer(SHARED_UNITS * 2, name="fusion_sentiment")(Gs, SPIAs)

    #Classification Layer (eq. 17 — final concat of private + shared)
    # Stance: concat(Ad, Fd_shared)
    stance_feat = tf.keras.layers.Concatenate(name="stance_features")([Ad, Fd_shared])
    stance_flat = tf.keras.layers.Flatten(name="stance_flat")(stance_feat)
    stance_h    = tf.keras.layers.Dense(64, activation="relu")(stance_flat)
    stance_h    = tf.keras.layers.Dropout(0.3)(stance_h)
    out_stance  = tf.keras.layers.Dense(1, activation="sigmoid",
                                        name="stance_output")(stance_h)

    # Sentiment: concat(As, Fs_shared)
    sent_feat   = tf.keras.layers.Concatenate(name="sentiment_features")([As, Fs_shared])
    sent_flat   = tf.keras.layers.Flatten(name="sentiment_flat")(sent_feat)
    sent_h      = tf.keras.layers.Dense(64, activation="relu")(sent_flat)
    sent_h      = tf.keras.layers.Dropout(0.3)(sent_h)
    out_sent    = tf.keras.layers.Dense(3, activation="softmax",
                                        name="sentiment_output")(sent_h)

    return tf.keras.Model(inputs=inp, outputs=[out_stance, out_sent], name="SP_AMT_USE")

# %%
#Compile & Train
print("Building SP-AMT with USE embeddings")

model = build_sp_amt()
model.summary()

model.compile(
    optimizer=tf.keras.optimizers.Adam(LEARNING_RATE),
    loss={
        "stance_output":    "binary_crossentropy",        # primary task
        "sentiment_output": "sparse_categorical_crossentropy"  # auxiliary
    },
    loss_weights={
        "stance_output":    1.0,       # Ltask
        "sentiment_output": LAMBDA     # λ·Lshared  (eq. 17)
    },
    metrics={
        "stance_output":    ["accuracy"],
        "sentiment_output": ["accuracy"]
    }
)

history = model.fit(
    X_train,
    {"stance_output": y_st_train, "sentiment_output": y_se_train},
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    validation_split=0.1,
    verbose=2
)
# Out:
# Building SP-AMT with USE embeddings
# Model: "SP_AMT_USE"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  use_embedding (InputLayer)  [(None, 1, 512)]             0         []
#
#  bilstm_private_stance (Bid  (None, 1, 200)               490400    ['use_embedding[0][0]']
#  irectional)
#
#  bilstm_shared (Bidirection  (None, 1, 200)               490400    ['use_embedding[0][0]']
#  al)
#
#  bilstm_private_sentiment (  (None, 1, 200)               490400    ['use_embedding[0][0]']
#  Bidirectional)
#
#  SA_stance (SelfAttention)   (None, 1, 100)               60300     ['bilstm_private_stance[0][0]'
#                                                                     ]
#
#  IA_stance_shared (InterAtt  (None, 1, 100)               60300     ['bilstm_private_stance[0][0]'
#  ention)                                                            , 'bilstm_shared[0][0]']
#
#  SA_sentiment (SelfAttentio  (None, 1, 100)               60300     ['bilstm_private_sentiment[0][
#  n)                                                                 0]']
#
#  IA_sentiment_shared (Inter  (None, 1, 100)               60300     ['bilstm_private_sentiment[0][
#  Attention)                                                         0]',
#                                                                      'bilstm_shared[0][0]']
#
#  tf.concat_4 (TFOpLambda)    (None, 1, 200)               0         ['SA_stance[0][0]',
#                                                                      'IA_stance_shared[0][0]']
#
#  tf.concat_5 (TFOpLambda)    (None, 1, 200)               0         ['SA_sentiment[0][0]',
#                                                                      'IA_sentiment_shared[0][0]']
#
#  A_shared (Average)          (None, 1, 200)               0         ['tf.concat_4[0][0]',
#                                                                      'tf.concat_5[0][0]']
#
#  gate_stance (GateSharingCe  (None, 1, 200)               40200     ['tf.concat_4[0][0]',
#  ll)                                                                 'A_shared[0][0]']
#
#  SPIA_stance (SPIALayer)     (None, 1, 200)               120600    ['tf.concat_4[0][0]',
#                                                                      'A_shared[0][0]']
#
#  gate_sentiment (GateSharin  (None, 1, 200)               40200     ['tf.concat_5[0][0]',
#  gCell)                                                              'A_shared[0][0]']
#
#  SPIA_sentiment (SPIALayer)  (None, 1, 200)               120600    ['tf.concat_5[0][0]',
#                                                                      'A_shared[0][0]']
#
#  fusion_stance (FusionLayer  (None, 1, 200)               160200    ['gate_stance[0][0]',
#  )                                                                   'SPIA_stance[0][0]']
#
#  fusion_sentiment (FusionLa  (None, 1, 200)               160200    ['gate_sentiment[0][0]',
#  yer)                                                                'SPIA_sentiment[0][0]']
#
#  stance_features (Concatena  (None, 1, 400)               0         ['tf.concat_4[0][0]',
#  te)                                                                 'fusion_stance[0][0]']
#
#  sentiment_features (Concat  (None, 1, 400)               0         ['tf.concat_5[0][0]',
#  enate)                                                              'fusion_sentiment[0][0]']
#
#  stance_flat (Flatten)       (None, 400)                  0         ['stance_features[0][0]']
#
#  sentiment_flat (Flatten)    (None, 400)                  0         ['sentiment_features[0][0]']
#
#  dense_71 (Dense)            (None, 64)                   25664     ['stance_flat[0][0]']
#
#  dense_72 (Dense)            (None, 64)                   25664     ['sentiment_flat[0][0]']
#
#  dropout_4 (Dropout)         (None, 64)                   0         ['dense_71[0][0]']
#
#  dropout_5 (Dropout)         (None, 64)                   0         ['dense_72[0][0]']
#
#  stance_output (Dense)       (None, 1)                    65        ['dropout_4[0][0]']
#
#  sentiment_output (Dense)    (None, 3)                    195       ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 2405988 (9.18 MB)
# Trainable params: 2405988 (9.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# Epoch 1/10
# 607/607 [==============================] - 94s 130ms/step - loss: 0.8252 - stance_output_loss: 0.3580 - sentiment_output_loss: 0.9344 - stance_output_accuracy: 0.8608 - sentiment_output_accuracy: 0.5495 - val_loss: 0.7247 - val_stance_output_loss: 0.3034 - val_sentiment_output_loss: 0.8426 - val_stance_output_accuracy: 0.8730 - val_sentiment_output_accuracy: 0.6194
# Epoch 2/10
# 607/607 [==============================] - 66s 108ms/step - loss: 0.7013 - stance_output_loss: 0.2995 - sentiment_output_loss: 0.8037 - stance_output_accuracy: 0.8804 - sentiment_output_accuracy: 0.6429 - val_loss: 0.7046 - val_stance_output_loss: 0.2938 - val_sentiment_output_loss: 0.8215 - val_stance_output_accuracy: 0.8776 - val_sentiment_output_accuracy: 0.6282
# Epoch 3/10
# 607/607 [==============================] - 84s 138ms/step - loss: 0.6832 - stance_output_loss: 0.2908 - sentiment_output_loss: 0.7846 - stance_output_accuracy: 0.8848 - sentiment_output_accuracy: 0.6575 - val_loss: 0.7028 - val_stance_output_loss: 0.2949 - val_sentiment_output_loss: 0.8159 - val_stance_output_accuracy: 0.8762 - val_sentiment_output_accuracy: 0.6361
# Epoch 4/10
# 607/607 [==============================] - 55s 90ms/step - loss: 0.6745 - stance_output_loss: 0.2853 - sentiment_output_loss: 0.7783 - stance_output_accuracy: 0.8877 - sentiment_output_accuracy: 0.6618 - val_loss: 0.6990 - val_stance_output_loss: 0.2905 - val_sentiment_output_loss: 0.8169 - val_stance_output_accuracy: 0.8781 - val_sentiment_output_accuracy: 0.6324
# Epoch 5/10
# 607/607 [==============================] - 66s 108ms/step - loss: 0.6673 - stance_output_loss: 0.2825 - sentiment_output_loss: 0.7697 - stance_output_accuracy: 0.8878 - sentiment_output_accuracy: 0.6666 - val_loss: 0.6967 - val_stance_output_loss: 0.2917 - val_sentiment_output_loss: 0.8100 - val_stance_output_accuracy: 0.8762 - val_sentiment_output_accuracy: 0.6356
# Epoch 6/10
# 607/607 [==============================] - 62s 103ms/step - loss: 0.6609 - stance_output_loss: 0.2795 - sentiment_output_loss: 0.7628 - stance_output_accuracy: 0.8891 - sentiment_output_accuracy: 0.6684 - val_loss: 0.6872 - val_stance_output_loss: 0.2844 - val_sentiment_output_loss: 0.8057 - val_stance_output_accuracy: 0.8804 - val_sentiment_output_accuracy: 0.6375
# Epoch 7/10
# 607/607 [==============================] - 64s 106ms/step - loss: 0.6539 - stance_output_loss: 0.2745 - sentiment_output_loss: 0.7589 - stance_output_accuracy: 0.8904 - sentiment_output_accuracy: 0.6716 - val_loss: 0.6864 - val_stance_output_loss: 0.2837 - val_sentiment_output_loss: 0.8053 - val_stance_output_accuracy: 0.8855 - val_sentiment_output_accuracy: 0.6379
# Epoch 8/10
# 607/607 [==============================] - 71s 118ms/step - loss: 0.6470 - stance_output_loss: 0.2718 - sentiment_output_loss: 0.7504 - stance_output_accuracy: 0.8919 - sentiment_output_accuracy: 0.6723 - val_loss: 0.6865 - val_stance_output_loss: 0.2824 - val_sentiment_output_loss: 0.8084 - val_stance_output_accuracy: 0.8822 - val_sentiment_output_accuracy: 0.6310
# Epoch 9/10
# 607/607 [==============================] - 62s 102ms/step - loss: 0.6433 - stance_output_loss: 0.2682 - sentiment_output_loss: 0.7503 - stance_output_accuracy: 0.8946 - sentiment_output_accuracy: 0.6758 - val_loss: 0.6871 - val_stance_output_loss: 0.2817 - val_sentiment_output_loss: 0.8108 - val_stance_output_accuracy: 0.8878 - val_sentiment_output_accuracy: 0.6282
# Epoch 10/10
# 607/607 [==============================] - 52s 85ms/step - loss: 0.6370 - stance_output_loss: 0.2650 - sentiment_output_loss: 0.7441 - stance_output_accuracy: 0.8955 - sentiment_output_accuracy: 0.6787 - val_loss: 0.6807 - val_stance_output_loss: 0.2790 - val_sentiment_output_loss: 0.8035 - val_stance_output_accuracy: 0.8878 - val_sentiment_output_accuracy: 0.6347

# %%
# Evaluate
from sklearn.metrics import accuracy_score, f1_score, recall_score


# Stance Metrics
acc_stance = accuracy_score(y_st_test, pred_stance) * 100
f1_stance_macro = f1_score(y_st_test, pred_stance, average="macro") * 100
rec_stance = recall_score(y_st_test, pred_stance, average="macro") * 100

# Sentiment Metrics
acc_sent = accuracy_score(y_se_test, pred_sent) * 100
f1_sent_macro = f1_score(y_se_test, pred_sent, average="macro") * 100
rec_sent = recall_score(y_se_test, pred_sent, average="macro") * 100

# --- Print Comparison Table ---
print("\n" + "="*50)
print(f"{'Metric':<20} | {'Your Model (Text Only)':<25}")
print("-" * 50)
print(f"{'Stance Accuracy':<20} | {acc_stance:>10.2f}%")
print(f"{'Stance F1 (Macro)':<20} | {f1_stance_macro:>10.2f}%")
print(f"{'Stance Recall (Macro)':<20} | {rec_stance:>10.2f}%")
print("-" * 50)
print(f"{'Sentiment Accuracy':<20} | {acc_sent:>10.2f}%")
print(f"{'Sentiment F1 (Macro)':<20} | {f1_sent_macro:>10.2f}%")
print(f"{'Sentiment Recall (Macro)':<20} | {rec_sent:>10.2f}%")
print("="*50)

# Optional: Print the detailed breakdown for your 'Analysis' section
print("\nDetailed Stance Report:")
print(classification_report(y_st_test, pred_stance, target_names=["Denier", "Believer"]))
# Out:
# ==================================================
# Metric               | Your Model (Text Only)
# --------------------------------------------------
# Stance Accuracy      |      88.61%
# Stance F1 (Macro)    |      69.31%
# Stance Recall (Macro) |      65.00%
# --------------------------------------------------
# Sentiment Accuracy   |      66.17%
# Sentiment F1 (Macro) |      63.76%
# Sentiment Recall (Macro) |      63.19%
# ==================================================
#
# Detailed Stance Report:
#               precision    recall  f1-score   support
#
#       Denier       0.79      0.31      0.45       798
#     Believer       0.89      0.99      0.94      4593
#
#     accuracy                           0.89      5391
#    macro avg       0.84      0.65      0.69      5391
# weighted avg       0.88      0.89      0.86      5391
